# %%
import pandas as pd
from pathlib import Path

# %%
input_path="C:/Users/Mohammed_Alam/learning/data/pandas_data/data.json"
events = events = pd.read_json(input_path)

# %%
events
# Out:
#       id                       name  \
# 0   3931            Anjushri Gandhi
# 1   3926     Sen. Harinarayan Sethi
# 2   3925             Gauranga Pilla
# 3   3924           Miss Daevika Jha
# 4   3923      The Hon. Ananda Devar
# 5   3922        Garuda Somayaji LLD
# 6   3921      Mrs. Chandrakin Marar
# 7   3917         Rageshwari Dwivedi
# 8   3915        Narinder Agarwal IV
# 9   3914               Daiwik Gupta
# 10  3913              Kanchan Varma
# 11  3912                Divya Desai
# 12  3911              Mohinder Gill
# 13  3910  Msgr. Brahma Bhattacharya
# 14  3909         Agniprava Singh MD
# 15  3908      Chidaakaash Ahluwalia
# 16  3907   Miss Dayaananda Prajapat
# 17  3906           Geetanjali Patel
# 18  3905               Aagneya Bhat
# 19  3904             Sitara Iyengar
#
#                                           email  gender    status
# 0                  gandhi_anjushri@schmitt.info    male  inactive
# ...

# %%
stats = events.groupby(["gender", "status"]).size().reset_index()
output_path="C:/Users/Mohammed_Alam/learning/data/pandas_data/stats.csv"

# %%
Path(output_path).parent.mkdir(exist_ok=True)

# %%
stats.to_csv(output_path, index=False)
